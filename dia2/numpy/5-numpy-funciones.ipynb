# %% [markdown]
# # FUNCIONES MAS COMUNES EN NUMPY

# %%
import numpy as np

# %% [markdown]
# # SHAPE Y RESHAPE

# %%
arr = np.random.randint(1,10,(3,2))
arr
# Out:
# array([[6, 1],
#        [5, 6],
#        [4, 9]])

# %%
arr.shape
# Out:
# (3, 2)

# %%
arr.ndim
# Out:
# 2

# %%
arr.reshape(1,6)
# Out:
# array([[6, 1, 5, 6, 4, 9]])

# %% [markdown]
# # MAX Y ARGMAX

# %%
arr = np.random.randint(1,20,10)
arr
# Out:
# array([ 6,  2,  8,  4,  3, 19, 12, 14,  5,  3])

# %%
matriz = arr.reshape(2,5)
matriz
# Out:
# array([[ 6,  2,  8,  4,  3],
#        [19, 12, 14,  5,  3]])

# %%
arr.max()
# Out:
# np.int64(19)

# %%
matriz.max()
# Out:
# np.int64(19)

# %%
arr.argmax()
# Out:
# np.int64(5)

# %%
matriz.argmax()
# Out:
# np.int64(5)

# %% [markdown]
# # MIN Y ARGMIN

# %%
arr.min()
# Out:
# np.int64(2)

# %%
matriz.min()
# Out:
# np.int64(2)

# %%
matriz.min(0)
# Out:
# array([6, 2, 8, 4, 3])

# %%
matriz.min(1)
# Out:
# array([2, 3])

# %% [markdown]
# # SORT

# %%
arr
# Out:
# array([ 6,  2,  8,  4,  3, 19, 12, 14,  5,  3])

# %%
arr.sort()
arr
# Out:
# array([ 2,  3,  3,  4,  5,  6,  8, 12, 14, 19])

# %%
arr2 = arr[::-1]
arr2
# Out:
# array([19, 14, 12,  8,  6,  5,  4,  3,  3,  2])
